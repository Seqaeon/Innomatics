# %%
import pandas as pd
import numpy as np
# from requests import get
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
from time import sleep
from random import randint
from warnings import warn
import requests
from urllib.request import Request, urlopen
import time
from tqdm import tqdm

# %%
movies = pd.read_csv('movies.csv')
links = pd.read_csv('links.csv')
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('tags.csv')

# %%
movies.shape
# Out:
# (9742, 3)

# %%
ratings.shape
# Out:
# (100836, 4)

# %%
ratings.nunique()
# Out:
# userId         610
# movieId       9724
# rating          10
# timestamp    85043
# dtype: int64

# %%
ratings["userId"].nunique()
# Out:
# 610

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
#df =movies.merge(ratings,  on='movieId', how='outer')
#df

# %%
movies['movieId'].nunique()
# Out:
# 9742

# %%
movies[movies['movieId'] ==ratings['movieId'].mode().item()]#['title']
# Out:
#      movieId                title                    genres
# 314      356  Forrest Gump (1994)  Comedy|Drama|Romance|War

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
tags[tags['movieId'] == movies[movies['title'] == 'Matrix, The (1999)']['movieId'].item()]['tag'].unique()
# Out:
# array(['martial arts', 'sci-fi', 'alternate universe', 'philosophy',
#        'post apocalyptic'], dtype=object)

# %%
ratings[ratings['movieId'] == movies[movies['title'] == 'Terminator 2: Judgment Day (1991)']['movieId'].item()]['rating'].mean()
# Out:
# 3.970982142857143

# %%
fight_club = ratings[ratings['movieId'] == movies[movies['title'] == 'Fight Club (1999)']['movieId'].item()]
fight_club
# Out:
#        userId  movieId  rating   timestamp
# 192         1     2959     5.0   964983282
# 458         4     2959     2.0   945078528
# 1134       10     2959     0.5  1455356582
# 1479       15     2959     2.5  1510571747
# 1635       16     2959     3.5  1377476874
# ...       ...      ...     ...         ...
# 95893     601     2959     5.0  1441639461
# 96788     603     2959     4.0   963176105
# 97835     606     2959     5.0  1171231517
# 99107     608     2959     5.0  1117336631
# 99699     610     2959     5.0  1479541966
#
# [218 rows x 4 columns]

# %%
sns.distplot(fight_club['rating'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='rating', ylabel='Density'>

# %%
sns.histplot(data =fight_club, x= 'rating', kde=True)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='Count'>

# %% [markdown]
# The distribution is left-skewed

# %% [markdown]
# 1. Group the user ratings based on movieId and apply aggregation operations like count and mean on ratings.
# 2. Apply inner join on dataframe created from movies.csv and the grouped df from step 1.
# 3. Filter only those movies which have more than 50 user ratings (i.e. > 50).

# %%
grouped_rating = ratings.groupby('movieId')['rating'].agg(['count',np. mean]).reset_index()
grouped_rating
# Out:
#       movieId  count      mean
# 0           1    215  3.920930
# 1           2    110  3.431818
# 2           3     52  3.259615
# 3           4      7  2.357143
# 4           5     49  3.071429
# ...       ...    ...       ...
# 9719   193581      1  4.000000
# 9720   193583      1  3.500000
# 9721   193585      1  3.500000
# 9722   193587      1  3.500000
# 9723   193609      1  4.000000
#
# [9724 rows x 3 columns]

# %%
grouped_rating['movieId']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 9719    193581
# 9720    193583
# 9721    193585
# 9722    193587
# 9723    193609
# Name: movieId, Length: 9724, dtype: int64

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
filtered_data = movies.merge(grouped_rating, on= 'movieId', how='inner')
filtered_data
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9719   193581  Black Butler: Book of the Atlantic (2017)
# 9720   193583               No Game No Life: Zero (2017)
# 9721   193585                               Flint (2017)
# 9722   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  count      mean
# 0     Adventure|Animation|Children|Comedy|Fantasy    215  3.920930
# 1                      Adventure|Children|Fantasy    110  3.431818
# 2                                  Comedy|Romance     52  3.259615
# ...

# %%
filtered_data = filtered_data[filtered_data['count'] > 50]
filtered_data
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8287   106782   Wolf of Wall Street, The (2013)
# 8354   109374  Grand Budapest Hotel, The (2014)
# 8358   109487               Interstellar (2014)
# 8457   112852    Guardians of the Galaxy (2014)
# 8673   122904                   Deadpool (2016)
#
#                                            genres  count      mean
# 0     Adventure|Animation|Children|Comedy|Fantasy    215  3.920930
# 1                      Adventure|Children|Fantasy    110  3.431818
# 2                                  Comedy|Romance     52  3.259615
# 5                           Action|Crime|Thriller    102  3.946078
# ...

# %%
filtered_data[filtered_data['mean'] == filtered_data['mean'].max()]
# Out:
#      movieId                             title       genres  count      mean
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama    317  4.429022

# %%
filtered_data['mean'].max()
# Out:
# 4.429022082018927

# %%
filtered_data.sort_values('count', ascending = False).head(5)
# Out:
#       movieId                             title                       genres  \
# 314       356               Forrest Gump (1994)     Comedy|Drama|Romance|War
# 277       318  Shawshank Redemption, The (1994)                  Crime|Drama
# 257       296               Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 510       593  Silence of the Lambs, The (1991)        Crime|Horror|Thriller
# 1938     2571                Matrix, The (1999)       Action|Sci-Fi|Thriller
#
#       count      mean
# 314     329  4.164134
# 277     317  4.429022
# 257     307  4.197068
# 510     279  4.161290
# 1938    278  4.192446

# %%
filtered_data[filtered_data['genres'].str.contains('Sci-Fi')].sort_values('count', ascending = False).iloc[2]
# Out:
# movieId                                 480
# title                  Jurassic Park (1993)
# genres     Action|Adventure|Sci-Fi|Thriller
# count                                   238
# mean                                   3.75
# Name: 418, dtype: object

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
linked_data = filtered_data.merge(links, on= 'movieId', how='inner')
linked_data
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# ...

# %%
linked_data['imdbRating'] = 0
headers = {'User-Agent': 'Mozilla/5.0'}
for i in tqdm(range(0, len(linked_data))):

    imdbId_str = str(linked_data.loc[i, 'imdbId']).zfill(7)
    req = Request(url="http://www.imdb.com/title/tt" + str(imdbId_str) + "/",headers=headers)
    webpage = urlopen(req).read()
    #response = requests.get("http://www.imdb.com/title/tt" + str(imdbId_str) + "/",headers=headers)
    page_html = BeautifulSoup(webpage, 'html.parser')
    imdbRating = float(page_html.find('span', class_ = 'sc-bde20123-1 cMEQkK').text)
    linked_data.loc[i, 'imdbRating'] = imdbRating
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 436/436 [24:08<00:00,  3.32s/it]

# %%
linked_data
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# ...

# %%
linked_data[linked_data['imdbRating'] == linked_data['imdbRating'].max()]
# Out:
#     movieId                             title       genres  count      mean  \
# 53      318  Shawshank Redemption, The (1994)  Crime|Drama    317  4.429022
#
#     imdbId  tmdbId  imdbRating
# 53  111161   278.0         9.3

# %%
linked_data[linked_data['genres'].str.contains('Sci-Fi')].sort_values('imdbRating', ascending = False)
# Out:
#      movieId                                              title  \
# 424    79132                                   Inception (2010)
# 248     2571                                 Matrix, The (1999)
# 433   109487                                Interstellar (2014)
# 140     1196  Star Wars: Episode V - The Empire Strikes Back...
# 44       260          Star Wars: Episode IV - A New Hope (1977)
# ..       ...                                                ...
# 36       173                                 Judge Dredd (1995)
# 35       172                             Johnny Mnemonic (1995)
# 73       435                                   Coneheads (1993)
# 30       160                                       Congo (1995)
# 260     2701                              Wild Wild West (1999)
#
#                                               genres  count      mean  \
# 424  Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX    143  4.066434
# ...

# %% [raw]
# # <http://www.imdb.com/title/tt0114709/>
# start_time = time.process_time()
#
# gen = '0113497'
# headers = headers={'User-Agent': 'Mozilla/5.0','Accept-Language': 'en-US,en;q=0.8'}
# response = requests.get("http://www.imdb.com/title/tt" + str(gen) + "/", headers = headers )#+ "/")#
#
#         #  + "&explore=title_type,genres&ref_=adv_prv", headers=headers)
# sleep(randint(5,20))
#
# if response.status_code != 200:
#     warn("Request: {}; Status Code: {}". format(requests, response.status_code))
#
# page_html = BeautifulSoup(response.content, 'html.parser')
# print('Time Taken is: ', time.process_time() - start_time)
#
# page_html
